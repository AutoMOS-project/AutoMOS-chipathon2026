# %% [markdown]
# Testing gLayout Flipped-Voltage-Follower (FVF)¶
# ==============================================
#
# Simple test of FVF

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from glayout.cells.elementary.FVF import flipped_voltage_follower
from glayout import MappedPDK, sky130 , gf180

# %%
pdk=gf180
pdk.activate()
# Out:
# 2026-08-07 20:15:54.921 | INFO     | gdsfactory.pdk:activate:337 - 'gf180' PDK is now active

# %%
fvf_sample=flipped_voltage_follower(pdk, 
                                    device_type="nmos",
                                    placement="horizontal",
                                    width=(1, 2),
                                    length=(2,4),
                                    fingers=(1,1),
                                    multipliers=(2,2))
fvf_sample.show()
# Out:
# 2026-08-07 20:33:35.408 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.4.3", "klayout_version": "0.30.2", "type": "open", "file": "/tmp/gdsfactory/flipped_voltage_follower_68251924$3.gds"}

# %%
fvf_sample=flipped_voltage_follower(pdk, 
                                    device_type="nmos",
                                    placement="vertical",
                                    width=(1, 2),
                                    length=(2,4),
                                    fingers=(1,1),
                                    multipliers=(2,2))
fvf_sample.show()
# Out:
# 2026-08-07 20:17:12.931 | WARNING  | gdsfactory.klive:show:48 - Could not connect to klive server. Is klayout open and klive plugin installed?
